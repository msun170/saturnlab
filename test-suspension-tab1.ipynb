# %% [markdown]
# # Tab 1: Active Notebook
# This tab stays active while Tab 2 gets suspended.

# %%
# Run this to start the kernel
import numpy as np
data = np.random.randn(1000, 100)
print(f'Tab 1 active: {data.shape} array using ~{data.nbytes / 1024 / 1024:.1f} MB')

# %%
# Run this periodically to confirm Tab 1 kernel is still alive
print(f'Tab 1 still running! data mean = {data.mean():.4f}')

# %% [markdown]
# ## Suspension Test Instructions
#
# 1. Open both `test-suspension-tab1.ipynb` and `test-suspension-tab2.ipynb`
# 2. Start kernels in both tabs and run the first code cell in each
# 3. Stay on THIS tab (Tab 1) and watch Tab 2:
#    - **After 5 minutes**: Tab 2 dims with a moon icon (Layer A: UI suspended)
#    - **After 30 minutes**: Tab 2 dims with a pause icon (Layer C: kernel stopped)
# 4. Click Tab 2 to see the suspended placeholder
# 5. Click 'Resume' or 'Resume and Restart Kernel' to bring it back
#
# **Quick test**: You can verify the tab icon changes by watching the tab bar.
# Tab 2 should go from normal to dimmed as time passes.
#
# **Note**: To speed up testing, Layer A triggers at 5 min and Layer C at 30 min.
# In production these would be configurable.
