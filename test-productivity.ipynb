# %% [markdown]
# # Productivity Features Test

# %%
# Cell 1
a = 10
print('Cell 1: a =', a)

# %%
# Cell 2
b = a * 2
print('Cell 2: b =', b)

# %%
# Cell 3
c = a + b
print('Cell 3: c =', c)

# %%
# Cell 4
print('Cell 4: sum =', a + b + c)

# %%
# Cell 5
print('Cell 5: all done!')

# %% [markdown]
# ## Test Instructions
#
# ### 1. Dirty Tab on Execution
# 1. Run Cell 1 (Shift+Enter)
# 2. Check the **tab** at the top: it should now show a **dot** indicating unsaved changes
# 3. Save with Ctrl+S: the dot should disappear
#
# ### 2. Confirm Before Closing Unsaved Tab
# 1. Run Cell 2 so the tab becomes dirty (dot appears)
# 2. Click the **X** on the tab to close it
# 3. You should see a dialog: **"test-productivity.ipynb has unsaved changes. Close anyway?"**
# 4. Click Cancel to keep the tab open
# 5. Save (Ctrl+S), then close: no dialog this time
#
# ### 3. Run All Above / Run All Below
# 1. Click on **Cell 3** to select it
# 2. Go to **Cell > Run All Above**: Cells 1 and 2 should execute, Cell 3 should NOT
# 3. Check outputs: Cell 1 shows "a = 10", Cell 2 shows "b = 20", Cell 3 has no output
# 4. Now go to **Cell > Run All Below**: Cells 3, 4, and 5 should execute
# 5. Check: Cell 3 shows "c = 30", Cell 4 shows "sum = 60", Cell 5 shows "all done!"
#
# ### 4. Auto-save
# 1. Make sure the file is saved first (Ctrl+S)
# 2. Run a cell to make it dirty (dot appears)
# 3. Wait 30 seconds without doing anything
# 4. The **dot should disappear** automatically (auto-saved)
# 5. Note: only works for files that have been saved at least once (not Untitled)
#
# ### 5. Command Palette
# 1. Press **Ctrl+Shift+P**
# 2. A search box should appear at the top with a list of all commands
# 3. Try typing: "run" to filter to run-related commands
# 4. Try typing: "cell" to filter to cell-related commands
# 5. Use **arrow keys** to navigate, **Enter** to execute
# 6. Try typing: "save" then pressing Enter to save
# 7. Press **Escape** to close the palette
# 8. Try clicking on a command instead of using Enter
