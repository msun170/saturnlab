# %% [markdown]
# # Settings Panel Test
# Test all configurable settings in Saturn.

# %%
# Run this first to start the kernel
print("Kernel started! Ready to test settings.")

# %%
# Use this cell to test font size changes
def hello_world():
    message = "Testing font size"
    for i in range(5):
        print(f"{message} - line {i}")
    return message

hello_world()

# %%
# Test auto-save interval
# 1. Open Settings, change auto-save to 10 seconds
# 2. Run this cell (makes tab dirty)
# 3. Wait 10 seconds - green Autosaved in status bar
print("Auto-save test - check status bar after waiting")

# %%
# Verify kernel is alive after Layer C test
import os
print(f"Kernel PID: {os.getpid()}")
print("If you see this, the kernel is running!")

# %% [markdown]
# ## Test Checklist
#
# ### Opening Settings
# - [ ] Go to Help > Settings
# - [ ] Settings panel opens as a modal
# - [ ] All fields show default values
# - [ ] Click Cancel to close without saving
#
# ### Kernel Auto-Stop (Layer C)
# 1. [ ] Change auto-stop to After 30 minutes, Save
# 2. [ ] Open a second notebook, start kernels in both
# 3. [ ] Stay on this tab for 30+ minutes
# 4. [ ] Other tab should show pause icon
#
# ### Suspension Delays
# 1. [ ] Change background suspension to 15 seconds
# 2. [ ] Change UI suspension to 60 seconds
# 3. [ ] Save, open second tab, switch away
# 4. [ ] After 1 minute the second tab dims with moon icon
#
# ### Auto-Save Interval
# 1. [ ] Change auto-save to 10 seconds, Save
# 2. [ ] Run a cell (makes tab dirty)
# 3. [ ] Wait 10 seconds, status bar shows green Autosaved
#
# ### Persistence
# 1. [ ] Change settings and save
# 2. [ ] Close and reopen Saturn
# 3. [ ] Settings should still be changed
