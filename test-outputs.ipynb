# %% [markdown]
# # Output Rendering Test
# Testing all output types in Saturn

# %%
# Test 1: Basic print
print('Hello from Saturn!')
# Out:
# Hello from Saturn!

# %%
# Test 2: Expression result (execute_result)
2 + 2
# Out:
# 4

# %%
# Test 3: HTML table via pandas DataFrame
import pandas as pd
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'Score': [88.5, 92.3, 76.1]})
df
# Out:
#       Name  Age  Score
# 0    Alice   25   88.5
# 1      Bob   30   92.3
# 2  Charlie   35   76.1

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# Test 4: Matplotlib plot
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, 'b-', label='sin(x)')
plt.plot(x, np.cos(x), 'r--', label='cos(x)')
plt.title('Trigonometric Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Test 5: Error traceback
this_will_fail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Test 5: Error traceback
# ----> 2 this_will_fail()
#
# NameError: name 'this_will_fail' is not defined

# %%
# Test 6: Multiple outputs from one cell
print('Line 1')
print('Line 2')
print('Line 3')
'final expression result'
# Out:
# Line 1
# Line 2
# Line 3
# 'final expression result'

# %%
# Test 7: Stderr output
import sys
print('This is stderr', file=sys.stderr)
print('This is stdout')
# Out:
# This is stdout
# This is stderr

# %%
# Test 8: Large DataFrame
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(20, 5), columns=['A', 'B', 'C', 'D', 'E'])
df

# %% [markdown]
# ## Math Test
#
# Inline math: $E = mc^2$
#
# Block math:
# $$\int_0^\infty e^{-x^2} dx = \frac{\sqrt{\pi}}{2}$$
