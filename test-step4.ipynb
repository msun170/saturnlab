# %% [markdown]
# # Step 4 Productivity Test
# Test all productivity features added in Step 4.

# %% [markdown]
# ## Section 1: Autocomplete & Tooltip

# %%
# Test Autocomplete:
# 1. Place cursor after 'import pa' and press Tab
# 2. You should see 'pandas', 'pathlib', etc.
import pa

# %%
# Test Tooltip:
# 1. Run this cell first to define the function
def greet(name, greeting='Hello'):
    """Greet someone with a custom message.
    
    Args:
        name: The person's name
        greeting: The greeting word (default: Hello)
    
    Returns:
        A greeting string
    """
    return f'{greeting}, {name}!'

print(greet('Saturn'))
# Out:
# Hello, Saturn!

# %%
# Now place cursor on 'greet' below and press Shift+Tab
# You should see the docstring popup
greet

# %%
# Also try Shift+Tab on built-in functions:
# Place cursor on 'print' and press Shift+Tab
print

# %% [markdown]
# ## Section 2: Collapsible Headings
# Click the small triangle to the left of this heading to collapse everything below until the next section.

# %%
# This cell should be hidden when Section 2 is collapsed
print('I am inside Section 2')

# %%
# This cell should also be hidden when Section 2 is collapsed
print('Still in Section 2')

# %% [markdown]
# ## Section 3: Search and Replace

# %%
# Test Search (Ctrl+F):
# 1. Press Ctrl+F
# 2. Type 'goodbye' in the search box
# 3. It should find matches in this cell
goodbye = 'goodbye world'
print(goodbye)
print('goodbye again')

# %%
# More 'hello' instances for search to find
message = 'say hello to saturn'
print(message)

# %%
# Test Replace:
# 1. Press Ctrl+F
# 2. Click the triangle to expand Replace
# 3. Search for 'goodbye', replace with 'goodbye'
# 4. Click Replace (replaces in focused cell) or All (replaces everywhere)

# %% [markdown]
# ## Section 4: Drag and Drop

# %%
# Cell A - Try dragging this cell below Cell B
print('I am Cell A')

# %%
# Cell B - Drag Cell A here
print('I am Cell B')

# %% [markdown]
# ## Section 5: Command Palette & Other

# %%
# Test Command Palette:
# 1. Press Ctrl+Shift+P
# 2. Type 'run' to filter run commands
# 3. Select 'Run All Cells' and press Enter
# 4. All code cells should execute

# Test Run All Above/Below:
# 1. Click on this cell
# 2. Go to Cell > Run All Above (cells above execute)
# 3. Go to Cell > Run All Below (cells below execute)

print('Command palette and run above/below test')

# %%
# Test Auto-save:
# 1. Save this file first (Ctrl+S)
# 2. Run this cell (makes the tab dirty, dot appears)
# 3. Wait 30 seconds
# 4. The dot should disappear and status bar shows green 'Autosaved at HH:MM:SS'

print('Auto-save test - wait 30 seconds after running this')

# %% [markdown]
# ## Test Checklist
#
# - [ ] **Autocomplete**: Type `import pa` + Tab shows completions
# - [ ] **Tooltip**: Cursor on `greet` + Shift+Tab shows docstring
# - [ ] **Tooltip built-in**: Cursor on `print` + Shift+Tab shows help
# - [ ] **Collapse Section 2**: Click triangle, cells 8-9 disappear
# - [ ] **Expand Section 2**: Click triangle again, cells reappear
# - [ ] **Search (Ctrl+F)**: Find 'hello' shows match count, Enter navigates
# - [ ] **Replace**: Replace 'hello' with 'goodbye' in one cell or all
# - [ ] **Match case**: Toggle case sensitivity in search
# - [ ] **Drag-and-drop**: Drag Cell A below Cell B
# - [ ] **Command palette (Ctrl+Shift+P)**: Opens, filter works, Enter executes
# - [ ] **Run All Above**: Cell menu, runs cells above current
# - [ ] **Run All Below**: Cell menu, runs cells below current
# - [ ] **Auto-save**: Dirty tab auto-saves after 30s, green message in status bar
# - [ ] **Close unsaved tab**: Shows native OS confirm dialog before closing
